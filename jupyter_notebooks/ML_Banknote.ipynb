# %% [markdown]
# # Machine Learning

# %% [markdown]
# # Exploring Banknote Authentication

# %% [markdown]
# ## Tensorflow - Classification

# %% [markdown]
# ## Introduction

# %% [markdown]
# The objective is to develop a classification model using the Bank Authentication dataset and Tensorflow
#
# The data set has 5 columns:
#
# - Image.Var: variance of Wavelet Transformed image (continuous)
# - Image.Skew: skewness of Wavelet Transformed image (continuous)
# - Image.Curt: curtosis of Wavelet Transformed image (continuous)
# - Entropy: entropy of image (continuous)
# - Class: class (integer)
#
# The Bank Authentication dataset contains two classes
#
# - Authentic banknote
# - Inauthentic banknote
#
# ##### Source: Pierian Data

# %% [markdown]
# ## Analysis

# %% [markdown]
# Import libraries

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
import tensorflow as tf

# %% [markdown]
# Load the Bank Authentication data set

# %%
df_bank = pd.read_csv("bank_note_data.csv")

# %% [markdown]
# Explore header/first 5 rows

# %%
df_bank.head()
# Out:
#    Image.Var  Image.Skew  Image.Curt  Entropy  Class
# 0    3.62160      8.6661     -2.8073 -0.44699      0
# 1    4.54590      8.1674     -2.4586 -1.46210      0
# 2    3.86600     -2.6383      1.9242  0.10645      0
# 3    3.45660      9.5228     -4.0112 -3.59440      0
# 4    0.32924     -4.4552      4.5718 -0.98880      0

# %% [markdown]
# Explore dimensions and missing data

# %%
df_bank.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1372 entries, 0 to 1371
# Data columns (total 5 columns):
# Image.Var     1372 non-null float64
# Image.Skew    1372 non-null float64
# Image.Curt    1372 non-null float64
# Entropy       1372 non-null float64
# Class         1372 non-null int64
# dtypes: float64(4), int64(1)
# memory usage: 53.7 KB

# %%
df_bank["Class"].value_counts()
# Out:
# 0    762
# 1    610
# Name: Class, dtype: int64

# %% [markdown]
# Columns should be formatted in snake format, there are not missing values and only two target values to classify

# %%
df_bank.columns
# Out:
# Index(['Image.Var', 'Image.Skew', 'Image.Curt', 'Entropy', 'Class'], dtype='object')

# %%
df_bank.columns = df_bank.columns.str.lower()
df_bank.columns = df_bank.columns.str.replace(".","_")

# %%
df_bank.columns
# Out:
# Index(['image_var', 'image_skew', 'image_curt', 'entropy', 'class'], dtype='object')

# %% [markdown]
# Define training and testing sets

# %%
X = df_bank[["image_var", "image_skew", "image_curt", "entropy"]]

# %%
y = df_bank["class"]

# %% [markdown]
# Data set = Train (70%) & Test (30%)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %% [markdown]
# ## Train Model

# %% [markdown]
# Define feature columns of type numeric using Tensorflow

# %%
feature_columns = []

# %%
for col in X.columns:
    feature_columns.append(tf.feature_column.numeric_column(col))

# %%
feature_columns
# Out:
# [_NumericColumn(key='image_var', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='image_skew', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='image_curt', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='entropy', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None)]

# %% [markdown]
# Define an input function

# %%
input_fn = tf.estimator.inputs.pandas_input_fn(x=X_train, y=y_train, batch_size=20, num_epochs=100, shuffle=True)

# %% [markdown]
# Because there are two target values to classify, n_classes is equal to 2 and the structure of the neural network should be tuned, actually it has three hidden layers, 10 neurons each

# %%
estimator = tf.estimator.DNNClassifier(hidden_units=[10,10,10],n_classes=2,feature_columns=feature_columns)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /var/folders/z6/vzs6bsnx4hn2qr27y9pzrrmw0000gn/T/tmp4yls9s2y
# INFO:tensorflow:Using config: {'_model_dir': '/var/folders/z6/vzs6bsnx4hn2qr27y9pzrrmw0000gn/T/tmp4yls9s2y', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0xb313d7160>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
estimator.train(input_fn=input_fn,steps=30)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into /var/folders/z6/vzs6bsnx4hn2qr27y9pzrrmw0000gn/T/tmp4yls9s2y/model.ckpt.
# INFO:tensorflow:loss = 20.002594, step = 1
# INFO:tensorflow:Saving checkpoints for 30 into /var/folders/z6/vzs6bsnx4hn2qr27y9pzrrmw0000gn/T/tmp4yls9s2y/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.3022642.

# %% [markdown]
# ## Test Model

# %% [markdown]
# Define an input function

# %%
prediction_fn = tf.estimator.inputs.pandas_input_fn(x=X_test,batch_size=len(X_test),shuffle=False)

# %%
predictions = list(estimator.predict(input_fn=prediction_fn))
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/z6/vzs6bsnx4hn2qr27y9pzrrmw0000gn/T/tmp4yls9s2y/model.ckpt-30
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.

# %% [markdown]
# Review the predictions

# %%
predictions
# Out:
# [{'logits': array([-10.277134], dtype=float32),
#   'logistic': array([3.4409826e-05], dtype=float32),
#   'probabilities': array([9.9996555e-01, 3.4409826e-05], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([2.3437798], dtype=float32),
#   'logistic': array([0.9124386], dtype=float32),
#   'probabilities': array([0.08756146, 0.9124386 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([2.0754838], dtype=float32),
#   'logistic': array([0.8884974], dtype=float32),
#   'probabilities': array([0.11150261, 0.8884974 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-13.092796], dtype=float32),
#   'logistic': array([2.0600128e-06], dtype=float32),
#   'probabilities': array([9.999980e-01, 2.060013e-06], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-8.068062], dtype=float32),
#   'logistic': array([0.00031329], dtype=float32),
#   'probabilities': array([9.9968672e-01, 3.1329194e-04], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-8.186466], dtype=float32),
#   'logistic': array([0.00027832], dtype=float32),
#   'probabilities': array([9.9972171e-01, 2.7831848e-04], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([3.5173645], dtype=float32),
#   'logistic': array([0.9711779], dtype=float32),
#   'probabilities': array([0.02882218, 0.9711779 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-8.350201], dtype=float32),
#   'logistic': array([0.00023629], dtype=float32),
#   'probabilities': array([9.9976367e-01, 2.3629324e-04], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([3.4845638], dtype=float32),
#   'logistic': array([0.9702453], dtype=float32),
#   'probabilities': array([0.02975464, 0.9702453 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-10.19982], dtype=float32),
#   'logistic': array([3.7175643e-05], dtype=float32),
#   'probabilities': array([9.9996281e-01, 3.7175643e-05], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-9.458439], dtype=float32),
#   'logistic': array([7.8022225e-05], dtype=float32),
#   'probabilities': array([9.999219e-01, 7.802222e-05], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-11.707209], dtype=float32),
#   'logistic': array([8.234179e-06], dtype=float32),
#   'probabilities': array([9.999918e-01, 8.234179e-06], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-9.270632], dtype=float32),
#   'logistic': array([9.4140145e-05], dtype=float32),
#   'probabilities': array([9.9990582e-01, 9.4140145e-05], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-11.148384], dtype=float32),
#   'logistic': array([1.4398328e-05], dtype=float32),
#   'probabilities': array([9.9998558e-01, 1.4398328e-05], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-9.991482], dtype=float32),
#   'logistic': array([4.578621e-05], dtype=float32),
#   'probabilities': array([9.999542e-01, 4.578621e-05], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-12.6597805], dtype=float32),
#   'logistic': array([3.1763313e-06], dtype=float32),
#   'probabilities': array([9.9999678e-01, 3.1763313e-06], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([3.0696452], dtype=float32),
#   'logistic': array([0.95562315], dtype=float32),
#   'probabilities': array([0.04437687, 0.95562315], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-12.366989], dtype=float32),
#   'logistic': array([4.2567976e-06], dtype=float32),
#   'probabilities': array([9.9999571e-01, 4.2567976e-06], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([2.542158], dtype=float32),
#   'logistic': array([0.9270449], dtype=float32),
#   'probabilities': array([0.0729551, 0.9270449], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-10.5043545], dtype=float32),
#   'logistic': array([2.741605e-05], dtype=float32),
#   'probabilities': array([9.9997258e-01, 2.7416052e-05], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([2.3067932], dtype=float32),
#   'logistic': array([0.90943813], dtype=float32),
#   'probabilities': array([0.09056191, 0.90943813], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-10.569206], dtype=float32),
#   'logistic': array([2.5694542e-05], dtype=float32),
#   'probabilities': array([9.9997425e-01, 2.5694540e-05], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-5.5428796], dtype=float32),
#   'logistic': array([0.00389997], dtype=float32),
#   'probabilities': array([0.99610007, 0.00389997], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-7.5424924], dtype=float32),
#   'logistic': array([0.00052979], dtype=float32),
#   'probabilities': array([9.9947017e-01, 5.2979396e-04], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-13.045061], dtype=float32),
#   'logistic': array([2.1607325e-06], dtype=float32),
#   'probabilities': array([9.9999785e-01, 2.1607327e-06], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([6.1555657], dtype=float32),
#   'logistic': array([0.9978828], dtype=float32),
#   'probabilities': array([0.00211715, 0.9978828 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([3.8018599], dtype=float32),
#   'logistic': array([0.9781585], dtype=float32),
#   'probabilities': array([0.0218415, 0.9781585], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-11.023727], dtype=float32),
#   'logistic': array([1.630981e-05], dtype=float32),
#   'probabilities': array([9.9998367e-01, 1.6309812e-05], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-11.818512], dtype=float32),
#   'logistic': array([7.3668575e-06], dtype=float32),
#   'probabilities': array([9.999926e-01, 7.366857e-06], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-10.515478], dtype=float32),
#   'logistic': array([2.7112783e-05], dtype=float32),
#   'probabilities': array([9.9997294e-01, 2.7112785e-05], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-6.998174], dtype=float32),
#   'logistic': array([0.00091271], dtype=float32),
#   'probabilities': array([9.9908733e-01, 9.1271463e-04], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-13.353088], dtype=float32),
#   'logistic': array([1.5879132e-06], dtype=float32),
#   'probabilities': array([9.9999845e-01, 1.5879131e-06], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-10.763437], dtype=float32),
#   'logistic': array([2.1158721e-05], dtype=float32),
#   'probabilities': array([9.9997890e-01, 2.1158723e-05], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([2.6738796], dtype=float32),
#   'logistic': array([0.93546766], dtype=float32),
#   'probabilities': array([0.06453237, 0.93546766], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-6.7809644], dtype=float32),
#   'logistic': array([0.00113389], dtype=float32),
#   'probabilities': array([0.9988661 , 0.00113389], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([2.7406962], dtype=float32),
#   'logistic': array([0.9393858], dtype=float32),
#   'probabilities': array([0.06061425, 0.9393858 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-9.480661], dtype=float32),
#   'logistic': array([7.6307624e-05], dtype=float32),
#   'probabilities': array([9.9992371e-01, 7.6307624e-05], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-11.709015], dtype=float32),
#   'logistic': array([8.21932e-06], dtype=float32),
#   'probabilities': array([9.999918e-01, 8.219320e-06], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([3.993453], dtype=float32),
#   'logistic': array([0.9818978], dtype=float32),
#   'probabilities': array([0.01810221, 0.9818978 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-9.044411], dtype=float32),
#   'logistic': array([0.00011804], dtype=float32),
#   'probabilities': array([9.99881983e-01, 1.18035074e-04], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-8.007992], dtype=float32),
#   'logistic': array([0.00033268], dtype=float32),
#   'probabilities': array([9.9966729e-01, 3.3268164e-04], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-8.221886], dtype=float32),
#   'logistic': array([0.00026864], dtype=float32),
#   'probabilities': array([9.9973136e-01, 2.6863572e-04], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-7.360412], dtype=float32),
#   'logistic': array([0.00063553], dtype=float32),
#   'probabilities': array([9.9936444e-01, 6.3553214e-04], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([6.0581536], dtype=float32),
#   'logistic': array([0.9976667], dtype=float32),
#   'probabilities': array([0.00233326, 0.9976667 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-8.665697], dtype=float32),
#   'logistic': array([0.00017237], dtype=float32),
#   'probabilities': array([9.9982762e-01, 1.7236962e-04], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-14.74448], dtype=float32),
#   'logistic': array([3.949603e-07], dtype=float32),
#   'probabilities': array([9.9999964e-01, 3.9496032e-07], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-11.414776], dtype=float32),
#   'logistic': array([1.1031157e-05], dtype=float32),
#   'probabilities': array([9.9998891e-01, 1.1031156e-05], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-8.428608], dtype=float32),
#   'logistic': array([0.00021848], dtype=float32),
#   'probabilities': array([9.9978155e-01, 2.1847775e-04], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-10.761757], dtype=float32),
#   'logistic': array([2.1194304e-05], dtype=float32),
#   'probabilities': array([9.9997878e-01, 2.1194304e-05], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-7.868648], dtype=float32),
#   'logistic': array([0.0003824], dtype=float32),
#   'probabilities': array([9.996176e-01, 3.824049e-04], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([1.8755441], dtype=float32),
#   'logistic': array([0.86709845], dtype=float32),
#   'probabilities': array([0.13290153, 0.86709845], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-9.974791], dtype=float32),
#   'logistic': array([4.6556816e-05], dtype=float32),
#   'probabilities': array([9.9995339e-01, 4.6556812e-05], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([6.6068807], dtype=float32),
#   'logistic': array([0.99865085], dtype=float32),
#   'probabilities': array([0.00134922, 0.99865085], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([2.2434635], dtype=float32),
#   'logistic': array([0.9040852], dtype=float32),
#   'probabilities': array([0.09591479, 0.9040852 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([2.162221], dtype=float32),
#   'logistic': array([0.8968053], dtype=float32),
#   'probabilities': array([0.10319473, 0.8968053 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-12.986063], dtype=float32),
#   'logistic': array([2.292047e-06], dtype=float32),
#   'probabilities': array([9.9999774e-01, 2.2920469e-06], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-11.879536], dtype=float32),
#   'logistic': array([6.9307494e-06], dtype=float32),
#   'probabilities': array([9.999931e-01, 6.930750e-06], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-12.164433], dtype=float32),
#   'logistic': array([5.212569e-06], dtype=float32),
#   'probabilities': array([9.9999475e-01, 5.2125688e-06], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([4.273223], dtype=float32),
#   'logistic': array([0.9862548], dtype=float32),
#   'probabilities': array([0.01374523, 0.9862548 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([1.4462228], dtype=float32),
#   'logistic': array([0.8094164], dtype=float32),
#   'probabilities': array([0.19058356, 0.8094164 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-14.121553], dtype=float32),
#   'logistic': array([7.3635454e-07], dtype=float32),
#   'probabilities': array([9.9999928e-01, 7.3635454e-07], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-10.482584], dtype=float32),
#   'logistic': array([2.801944e-05], dtype=float32),
#   'probabilities': array([9.9997199e-01, 2.8019438e-05], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([2.6872692], dtype=float32),
#   'logistic': array([0.9362712], dtype=float32),
#   'probabilities': array([0.06372876, 0.9362712 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-10.553099], dtype=float32),
#   'logistic': array([2.6111758e-05], dtype=float32),
#   'probabilities': array([9.9997389e-01, 2.6111758e-05], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([2.1884031], dtype=float32),
#   'logistic': array([0.8992033], dtype=float32),
#   'probabilities': array([0.10079674, 0.8992033 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-3.1650028], dtype=float32),
#   'logistic': array([0.04050418], dtype=float32),
#   'probabilities': array([0.9594958 , 0.04050418], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([4.381202], dtype=float32),
#   'logistic': array([0.98764426], dtype=float32),
#   'probabilities': array([0.01235573, 0.98764426], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-11.689671], dtype=float32),
#   'logistic': array([8.379863e-06], dtype=float32),
#   'probabilities': array([9.9999166e-01, 8.3798632e-06], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-13.883232], dtype=float32),
#   'logistic': array([9.3451973e-07], dtype=float32),
#   'probabilities': array([9.9999905e-01, 9.3451973e-07], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([3.8035507], dtype=float32),
#   'logistic': array([0.97819465], dtype=float32),
#   'probabilities': array([0.02180541, 0.97819465], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-14.807249], dtype=float32),
#   'logistic': array([3.7093113e-07], dtype=float32),
#   'probabilities': array([9.9999964e-01, 3.7093113e-07], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-13.302265], dtype=float32),
#   'logistic': array([1.6707017e-06], dtype=float32),
#   'probabilities': array([9.9999833e-01, 1.6707016e-06], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-12.152393], dtype=float32),
#   'logistic': array([5.275703e-06], dtype=float32),
#   'probabilities': array([9.9999475e-01, 5.2757032e-06], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([2.3930206], dtype=float32),
#   'logistic': array([0.91629356], dtype=float32),
#   'probabilities': array([0.08370647, 0.91629356], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([5.5561876], dtype=float32),
#   'logistic': array([0.9961514], dtype=float32),
#   'probabilities': array([0.00384861, 0.9961514 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([5.5918427], dtype=float32),
#   'logistic': array([0.9962857], dtype=float32),
#   'probabilities': array([0.0037143, 0.9962857], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-12.631226], dtype=float32),
#   'logistic': array([3.2683383e-06], dtype=float32),
#   'probabilities': array([9.9999678e-01, 3.2683386e-06], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([2.8327765], dtype=float32),
#   'logistic': array([0.9444215], dtype=float32),
#   'probabilities': array([0.05557848, 0.9444215 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([1.7077215], dtype=float32),
#   'logistic': array([0.8465405], dtype=float32),
#   'probabilities': array([0.15345949, 0.8465405 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([1.2715346], dtype=float32),
#   'logistic': array([0.7810053], dtype=float32),
#   'probabilities': array([0.21899466, 0.7810053 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-11.188517], dtype=float32),
#   'logistic': array([1.3831936e-05], dtype=float32),
#   'probabilities': array([9.99986172e-01, 1.38319365e-05], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([2.3217888], dtype=float32),
#   'logistic': array([0.9106656], dtype=float32),
#   'probabilities': array([0.08933443, 0.9106656 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([4.1421747], dtype=float32),
#   'logistic': array([0.9843603], dtype=float32),
#   'probabilities': array([0.01563977, 0.9843603 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-10.111073], dtype=float32),
#   'logistic': array([4.0625557e-05], dtype=float32),
#   'probabilities': array([9.9995935e-01, 4.0625557e-05], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-12.195169], dtype=float32),
#   'logistic': array([5.0547887e-06], dtype=float32),
#   'probabilities': array([9.9999499e-01, 5.0547887e-06], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-10.97835], dtype=float32),
#   'logistic': array([1.7066948e-05], dtype=float32),
#   'probabilities': array([9.9998295e-01, 1.7066950e-05], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([6.090093], dtype=float32),
#   'logistic': array([0.9977399], dtype=float32),
#   'probabilities': array([0.00226008, 0.9977399 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-10.991701], dtype=float32),
#   'logistic': array([1.68406e-05], dtype=float32),
#   'probabilities': array([9.9998319e-01, 1.6840599e-05], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-12.153595], dtype=float32),
#   'logistic': array([5.2693676e-06], dtype=float32),
#   'probabilities': array([9.9999475e-01, 5.2693672e-06], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([2.9542716], dtype=float32),
#   'logistic': array([0.95046496], dtype=float32),
#   'probabilities': array([0.04953501, 0.95046496], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([3.562266], dtype=float32),
#   'logistic': array([0.9724085], dtype=float32),
#   'probabilities': array([0.02759156, 0.9724085 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-11.731392], dtype=float32),
#   'logistic': array([8.03744e-06], dtype=float32),
#   'probabilities': array([9.99992e-01, 8.03744e-06], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([2.5797017], dtype=float32),
#   'logistic': array([0.92954373], dtype=float32),
#   'probabilities': array([0.07045627, 0.92954373], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-7.879474], dtype=float32),
#   'logistic': array([0.00037829], dtype=float32),
#   'probabilities': array([9.996216e-01, 3.782888e-04], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-10.396076], dtype=float32),
#   'logistic': array([3.0551197e-05], dtype=float32),
#   'probabilities': array([9.9996948e-01, 3.0551197e-05], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-9.7386265], dtype=float32),
#   'logistic': array([5.8957987e-05], dtype=float32),
#   'probabilities': array([9.9994099e-01, 5.8957987e-05], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-11.390629], dtype=float32),
#   'logistic': array([1.1300765e-05], dtype=float32),
#   'probabilities': array([9.99988675e-01, 1.13007645e-05], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([5.712114], dtype=float32),
#   'logistic': array([0.99670523], dtype=float32),
#   'probabilities': array([0.00329479, 0.99670523], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([2.5081954], dtype=float32),
#   'logistic': array([0.9247143], dtype=float32),
#   'probabilities': array([0.07528564, 0.9247143 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-11.23933], dtype=float32),
#   'logistic': array([1.3146652e-05], dtype=float32),
#   'probabilities': array([9.9998689e-01, 1.3146652e-05], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([4.223866], dtype=float32),
#   'logistic': array([0.9855694], dtype=float32),
#   'probabilities': array([0.01443064, 0.9855694 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-11.834238], dtype=float32),
#   'logistic': array([7.251913e-06], dtype=float32),
#   'probabilities': array([9.9999273e-01, 7.2519124e-06], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-7.612037], dtype=float32),
#   'logistic': array([0.00049422], dtype=float32),
#   'probabilities': array([9.9950576e-01, 4.9421919e-04], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([3.147542], dtype=float32),
#   'logistic': array([0.9588118], dtype=float32),
#   'probabilities': array([0.04118824, 0.9588118 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-12.304926], dtype=float32),
#   'logistic': array([4.5293577e-06], dtype=float32),
#   'probabilities': array([9.9999547e-01, 4.5293577e-06], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([3.1751673], dtype=float32),
#   'logistic': array([0.959889], dtype=float32),
#   'probabilities': array([0.04011099, 0.959889  ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([5.7354913], dtype=float32),
#   'logistic': array([0.9967811], dtype=float32),
#   'probabilities': array([0.0032189, 0.9967811], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([2.2636168], dtype=float32),
#   'logistic': array([0.90581864], dtype=float32),
#   'probabilities': array([0.09418137, 0.90581864], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([1.9561405], dtype=float32),
#   'logistic': array([0.87611467], dtype=float32),
#   'probabilities': array([0.12388534, 0.87611467], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([3.0653884], dtype=float32),
#   'logistic': array([0.95544225], dtype=float32),
#   'probabilities': array([0.04455774, 0.95544225], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-9.61837], dtype=float32),
#   'logistic': array([6.649149e-05], dtype=float32),
#   'probabilities': array([9.999335e-01, 6.649149e-05], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-11.035725], dtype=float32),
#   'logistic': array([1.6115311e-05], dtype=float32),
#   'probabilities': array([9.9998391e-01, 1.6115311e-05], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([5.7325425], dtype=float32),
#   'logistic': array([0.99677163], dtype=float32),
#   'probabilities': array([0.00322838, 0.99677163], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-5.9181876], dtype=float32),
#   'logistic': array([0.00268285], dtype=float32),
#   'probabilities': array([0.99731714, 0.00268285], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([1.9401093], dtype=float32),
#   'logistic': array([0.8743642], dtype=float32),
#   'probabilities': array([0.12563586, 0.8743642 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([2.9320405], dtype=float32),
#   'logistic': array([0.94940776], dtype=float32),
#   'probabilities': array([0.05059223, 0.94940776], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([2.1801682], dtype=float32),
#   'logistic': array([0.89845437], dtype=float32),
#   'probabilities': array([0.10154558, 0.89845437], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-9.732557], dtype=float32),
#   'logistic': array([5.931688e-05], dtype=float32),
#   'probabilities': array([9.9994063e-01, 5.9316877e-05], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-10.567003], dtype=float32),
#   'logistic': array([2.575121e-05], dtype=float32),
#   'probabilities': array([9.9997425e-01, 2.5751207e-05], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([2.2609758], dtype=float32),
#   'logistic': array([0.90559304], dtype=float32),
#   'probabilities': array([0.0944069 , 0.90559304], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([6.8573937], dtype=float32),
#   'logistic': array([0.99894947], dtype=float32),
#   'probabilities': array([0.00105055, 0.99894947], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-13.533432], dtype=float32),
#   'logistic': array([1.3258812e-06], dtype=float32),
#   'probabilities': array([9.9999869e-01, 1.3258812e-06], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-10.589159], dtype=float32),
#   'logistic': array([2.5186959e-05], dtype=float32),
#   'probabilities': array([9.9997485e-01, 2.5186961e-05], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-12.538437], dtype=float32),
#   'logistic': array([3.5861171e-06], dtype=float32),
#   'probabilities': array([9.9999642e-01, 3.5861174e-06], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-9.408104], dtype=float32),
#   'logistic': array([8.204965e-05], dtype=float32),
#   'probabilities': array([9.999180e-01, 8.204966e-05], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([4.3776035], dtype=float32),
#   'logistic': array([0.9876003], dtype=float32),
#   'probabilities': array([0.01239973, 0.9876003 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([2.3996816], dtype=float32),
#   'logistic': array([0.916803], dtype=float32),
#   'probabilities': array([0.08319698, 0.916803  ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([2.3035285], dtype=float32),
#   'logistic': array([0.90916884], dtype=float32),
#   'probabilities': array([0.09083115, 0.90916884], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-12.883024], dtype=float32),
#   'logistic': array([2.5408121e-06], dtype=float32),
#   'probabilities': array([9.9999750e-01, 2.5408124e-06], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([2.5425916], dtype=float32),
#   'logistic': array([0.92707425], dtype=float32),
#   'probabilities': array([0.07292577, 0.92707425], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([3.7527986], dtype=float32),
#   'logistic': array([0.97708535], dtype=float32),
#   'probabilities': array([0.02291463, 0.97708535], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([6.2863913], dtype=float32),
#   'logistic': array([0.998142], dtype=float32),
#   'probabilities': array([0.00185801, 0.998142  ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-14.8274], dtype=float32),
#   'logistic': array([3.6353126e-07], dtype=float32),
#   'probabilities': array([9.9999964e-01, 3.6353126e-07], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-12.960598], dtype=float32),
#   'logistic': array([2.3511632e-06], dtype=float32),
#   'probabilities': array([9.9999762e-01, 2.3511632e-06], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([6.0163255], dtype=float32),
#   'logistic': array([0.9975673], dtype=float32),
#   'probabilities': array([0.00243268, 0.9975673 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-11.326939], dtype=float32),
#   'logistic': array([1.2043919e-05], dtype=float32),
#   'probabilities': array([9.9998796e-01, 1.2043919e-05], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-10.799503], dtype=float32),
#   'logistic': array([2.0409221e-05], dtype=float32),
#   'probabilities': array([9.9997962e-01, 2.0409221e-05], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([2.1756053], dtype=float32),
#   'logistic': array([0.8980373], dtype=float32),
#   'probabilities': array([0.10196263, 0.8980373 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([1.5109578], dtype=float32),
#   'logistic': array([0.81920314], dtype=float32),
#   'probabilities': array([0.18079689, 0.81920314], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-13.226952], dtype=float32),
#   'logistic': array([1.8013874e-06], dtype=float32),
#   'probabilities': array([9.9999821e-01, 1.8013875e-06], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.27856272], dtype=float32),
#   'logistic': array([0.4308062], dtype=float32),
#   'probabilities': array([0.56919384, 0.4308062 ], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-12.72382], dtype=float32),
#   'logistic': array([2.9792984e-06], dtype=float32),
#   'probabilities': array([9.9999702e-01, 2.9792984e-06], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([3.2585387], dtype=float32),
#   'logistic': array([0.9629787], dtype=float32),
#   'probabilities': array([0.03702127, 0.9629787 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-10.349291], dtype=float32),
#   'logistic': array([3.201446e-05], dtype=float32),
#   'probabilities': array([9.9996793e-01, 3.2014461e-05], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([6.141414], dtype=float32),
#   'logistic': array([0.9978528], dtype=float32),
#   'probabilities': array([0.00214726, 0.9978528 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([2.9191327], dtype=float32),
#   'logistic': array([0.9487842], dtype=float32),
#   'probabilities': array([0.05121583, 0.9487842 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([7.4210324], dtype=float32),
#   'logistic': array([0.9994018], dtype=float32),
#   'probabilities': array([5.9817283e-04, 9.9940181e-01], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([2.1765742], dtype=float32),
#   'logistic': array([0.89812607], dtype=float32),
#   'probabilities': array([0.10187394, 0.89812607], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([2.3143165], dtype=float32),
#   'logistic': array([0.9100558], dtype=float32),
#   'probabilities': array([0.08994419, 0.9100558 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-11.285217], dtype=float32),
#   'logistic': array([1.25570305e-05], dtype=float32),
#   'probabilities': array([9.99987483e-01, 1.25570305e-05], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([3.5930629], dtype=float32),
#   'logistic': array([0.9732228], dtype=float32),
#   'probabilities': array([0.02677718, 0.9732228 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-12.392612], dtype=float32),
#   'logistic': array([4.1491103e-06], dtype=float32),
#   'probabilities': array([9.9999583e-01, 4.1491103e-06], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([1.9020269], dtype=float32),
#   'logistic': array([0.87012076], dtype=float32),
#   'probabilities': array([0.12987924, 0.87012076], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-6.054059], dtype=float32),
#   'logistic': array([0.00234281], dtype=float32),
#   'probabilities': array([0.9976572 , 0.00234281], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-14.541809], dtype=float32),
#   'logistic': array([4.836958e-07], dtype=float32),
#   'probabilities': array([9.999995e-01, 4.836958e-07], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([3.1589243], dtype=float32),
#   'logistic': array([0.9592589], dtype=float32),
#   'probabilities': array([0.04074107, 0.9592589 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-7.7935033], dtype=float32),
#   'logistic': array([0.00041224], dtype=float32),
#   'probabilities': array([9.9958771e-01, 4.1223556e-04], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-11.795332], dtype=float32),
#   'logistic': array([7.539614e-06], dtype=float32),
#   'probabilities': array([9.9999249e-01, 7.5396147e-06], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-8.76841], dtype=float32),
#   'logistic': array([0.00015555], dtype=float32),
#   'probabilities': array([9.9984443e-01, 1.5554659e-04], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([1.5543468], dtype=float32),
#   'logistic': array([0.8255407], dtype=float32),
#   'probabilities': array([0.17445935, 0.8255407 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-9.684553], dtype=float32),
#   'logistic': array([6.223361e-05], dtype=float32),
#   'probabilities': array([9.999378e-01, 6.223361e-05], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-7.0620437], dtype=float32),
#   'logistic': array([0.00085629], dtype=float32),
#   'probabilities': array([9.991437e-01, 8.562909e-04], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-10.436382], dtype=float32),
#   'logistic': array([2.9344317e-05], dtype=float32),
#   'probabilities': array([9.9997067e-01, 2.9344319e-05], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([3.4717612], dtype=float32),
#   'logistic': array([0.96987355], dtype=float32),
#   'probabilities': array([0.03012648, 0.96987355], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-10.32765], dtype=float32),
#   'logistic': array([3.2714805e-05], dtype=float32),
#   'probabilities': array([9.9996734e-01, 3.2714808e-05], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-12.68125], dtype=float32),
#   'logistic': array([3.1088655e-06], dtype=float32),
#   'probabilities': array([9.9999690e-01, 3.1088655e-06], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([2.4930737], dtype=float32),
#   'logistic': array([0.9236548], dtype=float32),
#   'probabilities': array([0.07634517, 0.9236548 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([6.5808015], dtype=float32),
#   'logistic': array([0.99861515], dtype=float32),
#   'probabilities': array([0.00138482, 0.99861515], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([1.6511842], dtype=float32),
#   'logistic': array([0.839051], dtype=float32),
#   'probabilities': array([0.16094896, 0.839051  ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-11.797062], dtype=float32),
#   'logistic': array([7.5265825e-06], dtype=float32),
#   'probabilities': array([9.999925e-01, 7.526583e-06], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-12.414417], dtype=float32),
#   'logistic': array([4.059619e-06], dtype=float32),
#   'probabilities': array([9.9999595e-01, 4.0596196e-06], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-10.325466], dtype=float32),
#   'logistic': array([3.2786327e-05], dtype=float32),
#   'probabilities': array([9.999672e-01, 3.278633e-05], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-13.206533], dtype=float32),
#   'logistic': array([1.8385464e-06], dtype=float32),
#   'probabilities': array([9.9999821e-01, 1.8385465e-06], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([5.5635343], dtype=float32),
#   'logistic': array([0.99617946], dtype=float32),
#   'probabilities': array([0.00382055, 0.99617946], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([1.8972328], dtype=float32),
#   'logistic': array([0.86957806], dtype=float32),
#   'probabilities': array([0.130422  , 0.86957806], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([6.675462], dtype=float32),
#   'logistic': array([0.99874014], dtype=float32),
#   'probabilities': array([0.0012599 , 0.99874014], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([2.0343595], dtype=float32),
#   'logistic': array([0.88435763], dtype=float32),
#   'probabilities': array([0.11564233, 0.88435763], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([3.0410357], dtype=float32),
#   'logistic': array([0.9543939], dtype=float32),
#   'probabilities': array([0.04560607, 0.9543939 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-9.972527], dtype=float32),
#   'logistic': array([4.6662335e-05], dtype=float32),
#   'probabilities': array([9.999534e-01, 4.666234e-05], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-7.694492], dtype=float32),
#   'logistic': array([0.00045512], dtype=float32),
#   'probabilities': array([9.9954480e-01, 4.5512101e-04], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([2.649687], dtype=float32),
#   'logistic': array([0.9339917], dtype=float32),
#   'probabilities': array([0.0660083, 0.9339917], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-3.1650028], dtype=float32),
#   'logistic': array([0.04050418], dtype=float32),
#   'probabilities': array([0.9594958 , 0.04050418], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([3.647746], dtype=float32),
#   'logistic': array([0.97461164], dtype=float32),
#   'probabilities': array([0.02538841, 0.97461164], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-11.376242], dtype=float32),
#   'logistic': array([1.1464524e-05], dtype=float32),
#   'probabilities': array([9.99988556e-01, 1.14645245e-05], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([2.1111999], dtype=float32),
#   'logistic': array([0.891987], dtype=float32),
#   'probabilities': array([0.10801302, 0.891987  ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([4.3056746], dtype=float32),
#   'logistic': array([0.98668784], dtype=float32),
#   'probabilities': array([0.01331218, 0.98668784], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([4.8369107], dtype=float32),
#   'logistic': array([0.99213094], dtype=float32),
#   'probabilities': array([0.00786911, 0.99213094], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-12.17313], dtype=float32),
#   'logistic': array([5.1674297e-06], dtype=float32),
#   'probabilities': array([9.9999487e-01, 5.1674297e-06], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([3.4857965], dtype=float32),
#   'logistic': array([0.9702809], dtype=float32),
#   'probabilities': array([0.02971908, 0.9702809 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-13.180439], dtype=float32),
#   'logistic': array([1.8871536e-06], dtype=float32),
#   'probabilities': array([9.9999809e-01, 1.8871535e-06], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-11.178961], dtype=float32),
#   'logistic': array([1.3964744e-05], dtype=float32),
#   'probabilities': array([9.9998605e-01, 1.3964744e-05], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([3.3237867], dtype=float32),
#   'logistic': array([0.9652358], dtype=float32),
#   'probabilities': array([0.03476411, 0.9652358 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([2.227388], dtype=float32),
#   'logistic': array([0.9026821], dtype=float32),
#   'probabilities': array([0.09731786, 0.9026821 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-6.8241706], dtype=float32),
#   'logistic': array([0.001086], dtype=float32),
#   'probabilities': array([0.998914, 0.001086], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-14.036863], dtype=float32),
#   'logistic': array([8.0143326e-07], dtype=float32),
#   'probabilities': array([9.9999917e-01, 8.0143320e-07], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-5.8730636], dtype=float32),
#   'logistic': array([0.00280634], dtype=float32),
#   'probabilities': array([0.99719363, 0.00280634], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-9.342602], dtype=float32),
#   'logistic': array([8.760352e-05], dtype=float32),
#   'probabilities': array([9.999124e-01, 8.760352e-05], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([2.8392684], dtype=float32),
#   'logistic': array([0.9447613], dtype=float32),
#   'probabilities': array([0.0552387, 0.9447613], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-11.896807], dtype=float32),
#   'logistic': array([6.8120767e-06], dtype=float32),
#   'probabilities': array([9.9999321e-01, 6.8120767e-06], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-12.565081], dtype=float32),
#   'logistic': array([3.4918316e-06], dtype=float32),
#   'probabilities': array([9.9999654e-01, 3.4918319e-06], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([3.49154], dtype=float32),
#   'logistic': array([0.9704461], dtype=float32),
#   'probabilities': array([0.02955391, 0.9704461 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([1.8170576], dtype=float32),
#   'logistic': array([0.8602127], dtype=float32),
# ...
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-7.043053], dtype=float32),
#   'logistic': array([0.00087269], dtype=float32),
#   'probabilities': array([9.9912733e-01, 8.7269343e-04], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([3.286405], dtype=float32),
#   'logistic': array([0.9639595], dtype=float32),
#   'probabilities': array([0.03604053, 0.9639595 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-11.3739605], dtype=float32),
#   'logistic': array([1.1490706e-05], dtype=float32),
#   'probabilities': array([9.9998856e-01, 1.1490706e-05], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-12.566612], dtype=float32),
#   'logistic': array([3.4864875e-06], dtype=float32),
#   'probabilities': array([9.9999654e-01, 3.4864877e-06], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([2.7099433], dtype=float32),
#   'logistic': array([0.9376108], dtype=float32),
#   'probabilities': array([0.06238917, 0.9376108 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.9940899], dtype=float32),
#   'logistic': array([0.729895], dtype=float32),
#   'probabilities': array([0.270105, 0.729895], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([4.0534716], dtype=float32),
#   'logistic': array([0.9829343], dtype=float32),
#   'probabilities': array([0.0170657, 0.9829343], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([3.9048314], dtype=float32),
#   'logistic': array([0.98025346], dtype=float32),
#   'probabilities': array([0.01974657, 0.98025346], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([2.4618862], dtype=float32),
#   'logistic': array([0.9214263], dtype=float32),
#   'probabilities': array([0.07857367, 0.9214263 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-10.833921], dtype=float32),
#   'logistic': array([1.971874e-05], dtype=float32),
#   'probabilities': array([9.9998033e-01, 1.9718740e-05], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-7.01739], dtype=float32),
#   'logistic': array([0.00089536], dtype=float32),
#   'probabilities': array([9.9910456e-01, 8.9535920e-04], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-8.282331], dtype=float32),
#   'logistic': array([0.00025288], dtype=float32),
#   'probabilities': array([9.997471e-01, 2.528828e-04], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-7.133423], dtype=float32),
#   'logistic': array([0.00079735], dtype=float32),
#   'probabilities': array([9.9920267e-01, 7.9734705e-04], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-12.636539], dtype=float32),
#   'logistic': array([3.251017e-06], dtype=float32),
#   'probabilities': array([9.999968e-01, 3.251017e-06], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([3.361229], dtype=float32),
#   'logistic': array([0.9664706], dtype=float32),
#   'probabilities': array([0.03352937, 0.9664706 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([1.447457], dtype=float32),
#   'logistic': array([0.8096068], dtype=float32),
#   'probabilities': array([0.19039325, 0.8096068 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-13.1050205], dtype=float32),
#   'logistic': array([2.034984e-06], dtype=float32),
#   'probabilities': array([9.9999797e-01, 2.0349842e-06], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-8.888411], dtype=float32),
#   'logistic': array([0.00013796], dtype=float32),
#   'probabilities': array([9.9986207e-01, 1.3795975e-04], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([2.026361], dtype=float32),
#   'logistic': array([0.8835371], dtype=float32),
#   'probabilities': array([0.11646284, 0.8835371 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-11.814192], dtype=float32),
#   'logistic': array([7.3987526e-06], dtype=float32),
#   'probabilities': array([9.999926e-01, 7.398752e-06], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-9.616144], dtype=float32),
#   'logistic': array([6.663965e-05], dtype=float32),
#   'probabilities': array([9.9993336e-01, 6.6639652e-05], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-8.500645], dtype=float32),
#   'logistic': array([0.0002033], dtype=float32),
#   'probabilities': array([9.9979669e-01, 2.0329589e-04], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([1.6469857], dtype=float32),
#   'logistic': array([0.8384832], dtype=float32),
#   'probabilities': array([0.16151677, 0.8384832 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([1.6528031], dtype=float32),
#   'logistic': array([0.8392695], dtype=float32),
#   'probabilities': array([0.16073047, 0.8392695 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-12.691738], dtype=float32),
#   'logistic': array([3.0764286e-06], dtype=float32),
#   'probabilities': array([9.9999690e-01, 3.0764286e-06], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-11.466537], dtype=float32),
#   'logistic': array([1.0474698e-05], dtype=float32),
#   'probabilities': array([9.9998951e-01, 1.0474697e-05], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([2.3789608], dtype=float32),
#   'logistic': array([0.9152088], dtype=float32),
#   'probabilities': array([0.08479117, 0.9152088 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-11.654575], dtype=float32),
#   'logistic': array([8.679175e-06], dtype=float32),
#   'probabilities': array([9.999913e-01, 8.679175e-06], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([6.1812716], dtype=float32),
#   'logistic': array([0.9979365], dtype=float32),
#   'probabilities': array([0.00206353, 0.9979365 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([4.8966374], dtype=float32),
#   'logistic': array([0.99258375], dtype=float32),
#   'probabilities': array([0.00741625, 0.99258375], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-11.0660305], dtype=float32),
#   'logistic': array([1.5634256e-05], dtype=float32),
#   'probabilities': array([9.9998438e-01, 1.5634258e-05], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([3.2665632], dtype=float32),
#   'logistic': array([0.9632637], dtype=float32),
#   'probabilities': array([0.03673625, 0.9632637 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-11.388332], dtype=float32),
#   'logistic': array([1.1326746e-05], dtype=float32),
#   'probabilities': array([9.9998868e-01, 1.1326746e-05], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([1.5668123], dtype=float32),
#   'logistic': array([0.8273287], dtype=float32),
#   'probabilities': array([0.1726713, 0.8273287], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-9.588289], dtype=float32),
#   'logistic': array([6.8521855e-05], dtype=float32),
#   'probabilities': array([9.9993145e-01, 6.8521855e-05], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-7.0604625], dtype=float32),
#   'logistic': array([0.00085764], dtype=float32),
#   'probabilities': array([9.991423e-01, 8.576448e-04], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([1.7895215], dtype=float32),
#   'logistic': array([0.85686857], dtype=float32),
#   'probabilities': array([0.14313139, 0.85686857], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([2.0166507], dtype=float32),
#   'logistic': array([0.88253427], dtype=float32),
#   'probabilities': array([0.11746576, 0.88253427], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([2.7645564], dtype=float32),
#   'logistic': array([0.9407302], dtype=float32),
#   'probabilities': array([0.0592698, 0.9407302], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([4.3592944], dtype=float32),
#   'logistic': array([0.987374], dtype=float32),
#   'probabilities': array([0.01262595, 0.987374  ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([5.8467097], dtype=float32),
#   'logistic': array([0.99711895], dtype=float32),
#   'probabilities': array([0.00288107, 0.99711895], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-9.621771], dtype=float32),
#   'logistic': array([6.626577e-05], dtype=float32),
#   'probabilities': array([9.999337e-01, 6.626576e-05], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([3.7289565], dtype=float32),
#   'logistic': array([0.9765454], dtype=float32),
#   'probabilities': array([0.02345456, 0.9765454 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-9.564926], dtype=float32),
#   'logistic': array([7.0141476e-05], dtype=float32),
#   'probabilities': array([9.9992990e-01, 7.0141476e-05], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-9.902136], dtype=float32),
#   'logistic': array([5.0065122e-05], dtype=float32),
#   'probabilities': array([9.9994993e-01, 5.0065126e-05], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([3.4101121], dtype=float32),
#   'logistic': array([0.968019], dtype=float32),
#   'probabilities': array([0.03198092, 0.968019  ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-10.188995], dtype=float32),
#   'logistic': array([3.7580212e-05], dtype=float32),
#   'probabilities': array([9.9996245e-01, 3.7580212e-05], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([4.801825], dtype=float32),
#   'logistic': array([0.9918522], dtype=float32),
#   'probabilities': array([0.00814781, 0.9918522 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([3.4189584], dtype=float32),
#   'logistic': array([0.96829176], dtype=float32),
#   'probabilities': array([0.03170819, 0.96829176], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([2.0435262], dtype=float32),
#   'logistic': array([0.8852919], dtype=float32),
#   'probabilities': array([0.11470817, 0.8852919 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-12.264549], dtype=float32),
#   'logistic': array([4.7159792e-06], dtype=float32),
#   'probabilities': array([9.9999523e-01, 4.7159792e-06], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([2.7432108], dtype=float32),
#   'logistic': array([0.93952876], dtype=float32),
#   'probabilities': array([0.06047123, 0.93952876], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-10.465456], dtype=float32),
#   'logistic': array([2.8503475e-05], dtype=float32),
#   'probabilities': array([9.9997151e-01, 2.8503477e-05], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([3.3080075], dtype=float32),
#   'logistic': array([0.9647025], dtype=float32),
#   'probabilities': array([0.0352975, 0.9647025], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([2.7227757], dtype=float32),
#   'logistic': array([0.93835723], dtype=float32),
#   'probabilities': array([0.06164271, 0.93835723], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-13.365782], dtype=float32),
#   'logistic': array([1.5678844e-06], dtype=float32),
#   'probabilities': array([9.9999845e-01, 1.5678845e-06], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([6.1152353], dtype=float32),
#   'logistic': array([0.99779594], dtype=float32),
#   'probabilities': array([0.00220409, 0.99779594], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-13.4026985], dtype=float32),
#   'logistic': array([1.5110588e-06], dtype=float32),
#   'probabilities': array([9.9999845e-01, 1.5110586e-06], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-10.536898], dtype=float32),
#   'logistic': array([2.653823e-05], dtype=float32),
#   'probabilities': array([9.999734e-01, 2.653823e-05], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([3.1554837], dtype=float32),
#   'logistic': array([0.9591242], dtype=float32),
#   'probabilities': array([0.04087575, 0.9591242 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-11.395369], dtype=float32),
#   'logistic': array([1.124733e-05], dtype=float32),
#   'probabilities': array([9.999888e-01, 1.124733e-05], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([2.6180933], dtype=float32),
#   'logistic': array([0.932017], dtype=float32),
#   'probabilities': array([0.06798301, 0.932017  ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([2.6530757], dtype=float32),
#   'logistic': array([0.93420035], dtype=float32),
#   'probabilities': array([0.06579969, 0.93420035], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([2.484841], dtype=float32),
#   'logistic': array([0.92307234], dtype=float32),
#   'probabilities': array([0.07692774, 0.92307234], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-11.56995], dtype=float32),
#   'logistic': array([9.445619e-06], dtype=float32),
#   'probabilities': array([9.999906e-01, 9.445619e-06], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-12.77582], dtype=float32),
#   'logistic': array([2.8283343e-06], dtype=float32),
#   'probabilities': array([9.9999714e-01, 2.8283341e-06], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([3.052687], dtype=float32),
#   'logistic': array([0.9548984], dtype=float32),
#   'probabilities': array([0.04510161, 0.9548984 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)}]

# %% [markdown]
# ## Results

# %% [markdown]
# Confusion matrix and classification report will be used in order to evaluate the results

# %%
predictions_single_vals = []

for prediction in predictions:
    predictions_single_vals.append(prediction["class_ids"][0])

# %%
print(confusion_matrix(y_test,predictions_single_vals))
# Out:
# [[230   1]
#  [  2 179]]

# %% [markdown]
# 409 correct predictions of a total of 412, 1 and 2 incorrect predictions respectively

# %%
print(classification_report(y_test,predictions_single_vals))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99       231
#            1       0.99      0.99      0.99       181
#
#    micro avg       0.99      0.99      0.99       412
#    macro avg       0.99      0.99      0.99       412
# weighted avg       0.99      0.99      0.99       412

# %% [markdown]
# As a result a f1 value of 99% which represents a high accuracy of the model
