# %% [markdown]
# # SAP

# %% [markdown]
# # SAP BTP

# %% [markdown]
# # SAP API Management

# %% [markdown]
# ## Objective

# %% [markdown]
# Develop an integration flow - HTTPS Adapter and expose the endpoint as a managed API on SAP API Management. Apply authentication policies and some others.

# %% [markdown]
# ### Requirements

# %% [markdown]
# Software and online services
# * SAP BTP [Trial Edition]

# %% [markdown]
# # SAP BTP

# %% [markdown]
# ## Integration Suite

# %% [markdown]
# ### Integration Flow - HTTPS Adapter

# %% [markdown]
# ![title](../images/sap_btp_api_00.png)

# %% [markdown]
# ## Test

# %% [markdown]
# ![title](../images/sap_btp_api_01.png)

# %% [markdown]
# ## SAP API Management

# %% [markdown]
# ## API Provider

# %% [markdown]
# ![title](../images/sap_btp_api_02.png)

# %% [markdown]
# ## API Proxy

# %% [markdown]
# ![title](../images/sap_btp_api_03.png)

# %% [markdown]
# ## Test

# %% [markdown]
# ![title](../images/sap_btp_api_04.png)

# %% [markdown]
# ## Apply policies

# %% [markdown]
# ![title](../images/sap_btp_api_05.png)

# %% [markdown]
# ## Product

# %% [markdown]
# ![title](../images/sap_btp_api_07.png)

# %% [markdown]
# ## Test

# %% [markdown]
# ### Invalid API Key

# %% [markdown]
# ![title](../images/sap_btp_api_06.png)

# %% [markdown]
# ### Valid API Key

# %% [markdown]
# ![title](../images/sap_btp_api_08.png)
