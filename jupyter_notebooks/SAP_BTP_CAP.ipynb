# %% [markdown]
# # SAP

# %% [markdown]
# # SAP BTP

# %% [markdown]
# # SAP CAP

# %% [markdown]
# ## Objective

# %% [markdown]
# Create a CAP project using local data.

# %% [markdown]
# ### Requirements

# %% [markdown]
# Software and online services
# * SAP BTP [Trial Edition]

# %% [markdown]
# # SAP Business Aplication Studio

# %% [markdown]
# ## Schema

# %% [markdown]
# ![title](../images/sap_btp_cap_01.png)

# %% [markdown]
# ## Service

# %% [markdown]
# ![title](../images/sap_btp_cap_02.png)

# %% [markdown]
# ## Data

# %% [markdown]
# ![title](../images/sap_btp_cap_03.png)

# %% [markdown]
# ## OData Service

# %% [markdown]
# ### JSON

# %% [markdown]
# {
#   "@odata.context": "$metadata#Listings",
#   "value": [
#     {
#       "ID": "24dfb5bd-b8c7-43f1-b9fa-cdccfcb05bf4",
#       "Title": "Stunning Downtown Houston Condo w/ Pool",
#       "Type": "Rent",
#       "Bedrooms": 2,
#       "Bathroms": 3,
#       "Parking": 1,
#       "City": "Houston",
#       "State": "Texas",
#       "Country": "USA",
#       "LastUpdatedAt": "2026-07-07T10:22:00.000Z"
#     },
#     {
#       "ID": "9f8e4e96-a1a7-47bf-a11b-cc6d5079a4de",
#       "Title": "New Construction Austin Home",
#       "Type": "Sale",
#       "Bedrooms": 3,
#       "Bathroms": 2,
#       "Parking": 1,
#       "City": "Austin",
#       "State": "Texas",
#       "Country": "USA",
#       "LastUpdatedAt": "2026-07-08T09:10:00.000Z"
#     },
#     {
#       "ID": "d4e5f768-bb88-4bb9-90b4-3ec937a09880",
#       "Title": "Elegant Hill Country Home for Sale",
#       "Type": "Sale",
#       "Bedrooms": 4,
#       "Bathroms": 1,
#       "Parking": 1,
#       "City": "Austin",
#       "State": "Texas",
#       "Country": "USA",
#       "LastUpdatedAt": "2026-07-06T11:06:00.000Z"
#     }
#   ]
# }

# %% [markdown]
# ### Fiori preview

# %% [markdown]
# ![title](../images/sap_btp_cap_04.png)
