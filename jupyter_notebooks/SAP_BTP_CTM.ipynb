# %% [markdown]
# # SAP

# %% [markdown]
# # SAP BTP

# %% [markdown]
# # Cloud Transport Management

# %% [markdown]
# # DEV - QAS - PRD

# %% [markdown]
# ## Objective

# %% [markdown]
# Create a multi-landscape configuration, build a SAP Fiori application and transport it using Cloud Transport Management across three stages DEV, QAS and PRD.

# %% [markdown]
# ### Requirements

# %% [markdown]
# Software and online services
# * SAP BTP [Trial Edition]

# %% [markdown]
# # SAP BTP

# %% [markdown]
# ## Landscape

# %% [markdown]
# ![title](../images/sap_btp_ctm_00.png)

# %% [markdown]
# ## Transport Nodes

# %% [markdown]
# ![title](../images/sap_btp_ctm_01.png)

# %% [markdown]
# ## Transport Routes

# %% [markdown]
# ![title](../images/sap_btp_ctm_02.png)

# %% [markdown]
# ## Lanscape Visualization

# %% [markdown]
# ![title](../images/sap_btp_ctm_03.png)

# %% [markdown]
# ## SAP Build Work Zone - DEV

# %% [markdown]
# ### Site Directory

# %% [markdown]
# ![title](../images/sap_btp_ctm_04.png)

# %% [markdown]
# ## SAP Build Work Zone - QAS

# %% [markdown]
# ### Site Directory

# %% [markdown]
# ![title](../images/sap_btp_ctm_05.png)

# %% [markdown]
# ## SAP Build Work Zone - PRD

# %% [markdown]
# ### Site Directory

# %% [markdown]
# ![title](../images/sap_btp_ctm_06.png)

# %% [markdown]
# ## Transport Nodes

# %% [markdown]
# ### DEV to QAS

# %% [markdown]
# ![title](../images/sap_btp_ctm_07.png)

# %% [markdown]
# ### QAS to PRD

# %% [markdown]
# ![title](../images/sap_btp_ctm_08.png)

# %% [markdown]
# ## Application

# %% [markdown]
# ![title](../images/sap_btp_ctm_09.png)
