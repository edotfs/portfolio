# %% [markdown]
# # SAP

# %% [markdown]
# # SAP BTP

# %% [markdown]
# # Cloud Transport Management

# %% [markdown]
# # DEV - QAS

# %% [markdown]
# ## Objective

# %% [markdown]
# Create a multi-landscape configuration, build an iflow and transport it using Cloud Transport Management across two stages DEV and QAS.

# %% [markdown]
# ### Requirements

# %% [markdown]
# Software and online services
# * SAP BTP [Trial Edition]
# * SAP Cloud Transport Management
# * Integration Suite

# %% [markdown]
# # SAP BTP

# %% [markdown]
# ## Landscape

# %% [markdown]
# ![title](../images/sap_btp_ctm_iflow_00.png)

# %% [markdown]
# ## Subaccount: portfolio-dev

# %% [markdown]
# ## SAP Integration Suite

# %% [markdown]
# ### iflow - HTTPS Adapter

# %% [markdown]
# ![title](../images/sap_btp_ctm_iflow_01.png)

# %% [markdown]
# ### Destinations + Transport Mode

# %% [markdown]
# ![title](../images/sap_btp_ctm_iflow_02.png)

# %% [markdown]
# ### Artifact

# %% [markdown]
# ![title](../images/sap_btp_ctm_iflow_03.png)

# %% [markdown]
# ### Transport

# %% [markdown]
# ![title](../images/sap_btp_ctm_iflow_04.png)

# %% [markdown]
# ### Transport Request ID

# %% [markdown]
# ![title](../images/sap_btp_ctm_iflow_05.png)

# %% [markdown]
# ## Subaccount: cloud-transport-management

# %% [markdown]
# ## Cloud Transport Management

# %% [markdown]
# ### Landscape Visualization

# %% [markdown]
# ![title](../images/sap_btp_ctm_iflow_06.png)

# %% [markdown]
# ### Transport Request

# %% [markdown]
# ![title](../images/sap_btp_ctm_iflow_07.png)

# %% [markdown]
# ### Import

# %% [markdown]
# ![title](../images/sap_btp_ctm_iflow_08.png)

# %% [markdown]
# ### Status

# %% [markdown]
# ![title](../images/sap_btp_ctm_iflow_09.png)

# %% [markdown]
# The artifacts and configuration process between subaccounts were successfully developed, unfortunately trial accounts restrict to only one SAP Integration Suite tenant globally.
#
# Because of that restriction, the transport process to portfolio-qas subaccount couldn’t be completed.
#
# 💡 The use of a second trial account could resolve the issue.
