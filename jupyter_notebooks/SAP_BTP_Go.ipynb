# %% [markdown]
# # SAP

# %% [markdown]
# # SAP BTP

# %% [markdown]
# # Cloud Foundry

# %% [markdown]
# # Application - Go

# %% [markdown]
# ## Objective

# %% [markdown]
# Build a Go application and deploy it using Cloud Foundry.

# %% [markdown]
# ### Requirements

# %% [markdown]
# Software and online services
# * SAP BTP [Trial Edition]

# %% [markdown]
# # Go

# %% [markdown]
# ## Local

# %% [markdown]
# ![title](../images/sap_btp_go_01.png)

# %% [markdown]
# # SAP BTP

# %% [markdown]
# ## Cloud Foundry

# %% [markdown]
# ## Deployment

# %% [markdown]
# cf push

# %% [markdown]
# ![title](../images/sap_btp_go_02.png)

# %% [markdown]
# ## Application

# %% [markdown]
# ![title](../images/sap_btp_go_03.png)

# %% [markdown]
# ![title](../images/sap_btp_go_04.png)

# %% [markdown]
# ## Instances

# %% [markdown]
# cf scale

# %% [markdown]
# ![title](../images/sap_btp_go_05.png)
