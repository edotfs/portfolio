# %% [markdown]
# # SAP

# %% [markdown]
# # SAP BTP

# %% [markdown]
# # Cloud Foundry

# %% [markdown]
# # Application - Node.js

# %% [markdown]
# ## Objective

# %% [markdown]
# Build a Node.js application and deploy it using Cloud Foundry.

# %% [markdown]
# ### Requirements

# %% [markdown]
# Software and online services
# * SAP BTP [Trial Edition]

# %% [markdown]
# # Node.js

# %% [markdown]
# ## Local

# %% [markdown]
# ![title](../images/sap_btp_node_01.png)

# %% [markdown]
# # SAP BTP

# %% [markdown]
# ## Cloud Foundry

# %% [markdown]
# ## Deployment

# %% [markdown]
# cf push

# %% [markdown]
# ![title](../images/sap_btp_node_02.png)

# %% [markdown]
# ## Application

# %% [markdown]
# ![title](../images/sap_btp_node_03.png)

# %% [markdown]
# ![title](../images/sap_btp_node_04.png)

# %% [markdown]
# ## Instances

# %% [markdown]
# cf scale

# %% [markdown]
# ![title](../images/sap_btp_node_05.png)
