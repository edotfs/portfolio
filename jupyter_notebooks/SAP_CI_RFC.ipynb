# %% [markdown]
# # SAP

# %% [markdown]
# # SAP BTP - Integration Suite

# %% [markdown]
# # Cloud Integration

# %% [markdown]
# # HTTP to RFC Scenario

# %% [markdown]
# ## Requirements

# %% [markdown]
# Hardware, software and online services

# %% [markdown]
# * M-Series Apple Chip
# * SAP BTP - Integration Suite [Trial Edition]
# * ABAP Cloud Developer Trial 2022 SP01
# * Docker Desktop
# * Cloud Connector
# * Postman

# %% [markdown]
# ## Docker Desktop

# %% [markdown]
# ### Image

# %% [markdown]
# ![title](../images/sap_ci_rfc_01.png)

# %% [markdown]
# ### Container

# %% [markdown]
# ![title](../images/sap_ci_rfc_02.png)

# %% [markdown]
# ## ABAP Platform Trial
# ### ABAP Cloud Developer Trial 2022 SP01

# %% [markdown]
# ![title](../images/sap_ci_rfc_03.png)

# %% [markdown]
# ### Function Module

# %% [markdown]
# ![title](../images/sap_ci_rfc_04.png)

# %% [markdown]
# ## Cloud Connector
# https://<the container's IP>:8443
# ### Subaccount

# %% [markdown]
# ![title](../images/sap_ci_rfc_05.png)

# %% [markdown]
# ### RFC

# %% [markdown]
# ![title](../images/sap_ci_rfc_06.png)

# %% [markdown]
# ## SAP BTP - Subaccount - Destination Configuration
# ### RFC

# %% [markdown]
#  ![title](../images/sap_ci_rfc_07.png)

# %% [markdown]
# ## SAP Integration Suite
# ### iFlow

# %% [markdown]
# ![title](../images/sap_ci_rfc_08.png)

# %% [markdown]
# # Postman

# %% [markdown]
# ![title](../images/sap_ci_rfc_09.png)
